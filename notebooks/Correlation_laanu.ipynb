# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Read CSV in as DataFrame

# %%
#Energy Production data read in and "year" set as index
Energy_Production_data = Path("../data/Total_Energy_Production.csv") 
Energy_Production = pd.read_csv(Energy_Production_data, index_col="Year")
Energy_Production.head()
# Out:
#       Crude Oil and Lease Condensate quads  Natural Gas Plant Liquids quads  \
# Year
# 2050                             24.796230                         8.190884
# 2049                             25.881308                         8.390840
# 2048                             26.494122                         8.449029
# 2047                             27.029858                         8.443357
# 2046                             27.620865                         8.467919
#
#       Dry Natural Gas quads  Coal quads  Nuclear quads  Hydropower quads  \
# Year
# 2050              46.616814   10.675206       6.716295          2.262525
# 2049              46.380791   10.649560       6.711448          2.273778
# 2048              46.018311   10.674273       6.708094          2.279950
# 2047              45.565365   10.683536       6.705318          2.281751
# 2046              45.196522   10.700363       6.700862          2.273704
#
# ...

# %%
# Non-renewable Energy Production
nonrenewable_production = Energy_Production.loc[:, ['Crude Oil and Lease Condensate quads', 'Natural Gas Plant Liquids quads', 'Dry Natural Gas quads', 'Coal quads','Nuclear quads', 'Other quads']]
nonrenewable_production.head()
# Out:
#       Crude Oil and Lease Condensate quads  Natural Gas Plant Liquids quads  \
# Year
# 2050                             24.796230                         8.190884
# 2049                             25.881308                         8.390840
# 2048                             26.494122                         8.449029
# 2047                             27.029858                         8.443357
# 2046                             27.620865                         8.467919
#
#       Dry Natural Gas quads  Coal quads  Nuclear quads  Other quads
# Year
# 2050              46.616814   10.675206       6.716295     0.771613
# 2049              46.380791   10.649560       6.711448     0.771784
# 2048              46.018311   10.674273       6.708094     0.763026
# 2047              45.565365   10.683536       6.705318     0.752588
# 2046              45.196522   10.700363       6.700862     0.732407

# %%
#Read in Energy consumption data and "year" set as index  
Energy_Consumption_data = Path("../data/Total_Energy_Use.csv")
Energy_Consumption = pd.read_csv(Energy_Consumption_data, index_col="Year")
Energy_Consumption.head()
# Out:
#       Liquid Fuels quads  Natural Gas quads  Coal quads  Nuclear quads  \
# Year
# 2050           38.663658          37.810448    7.936447       6.716295
# 2049           38.416660          37.552456    7.910830       6.711448
# 2048           38.181633          37.169861    7.944196       6.708094
# 2047           37.954109          36.785000    7.953084       6.705318
# 2046           37.730907          36.443565    7.962496       6.700862
#
#       Hydropower quads  Biomass quads  Other Renewable Energy quads  \
# Year
# 2050          2.262525       3.593170                     12.642707
# 2049          2.273778       3.570926                     12.415702
# 2048          2.279950       3.546339                     12.214866
# 2047          2.281751       3.524088                     12.039868
# 2046          2.273704       3.496759                     11.799397
#
#       Other quads  Total quads
# Year
# 2050     0.299321   109.924576
# 2049     0.300562   109.152359
# ...

# %%
Nonrenewable_Consumption = Energy_Consumption.loc[:, ['Liquid Fuels quads', 'Natural Gas quads', 'Coal quads','Nuclear quads']]
Nonrenewable_Consumption.head()
# Out:
#       Liquid Fuels quads  Natural Gas quads  Coal quads  Nuclear quads
# Year
# 2050           38.663658          37.810448    7.936447       6.716295
# 2049           38.416660          37.552456    7.910830       6.711448
# 2048           38.181633          37.169861    7.944196       6.708094
# 2047           37.954109          36.785000    7.953084       6.705318
# 2046           37.730907          36.443565    7.962496       6.700862

# %%
#Read in norminal price  set data and "year" as index  
Energy_Norminal_Price_data = Path("../data/Total_Energy_Nominal_Prices.csv")
Energy_Norminal_Price = pd.read_csv(Energy_Norminal_Price_data, index_col="Year")
Energy_Norminal_Price.head()
# Out:
#       Brent (nom $/b) nom $/b  West Texas Intermediate (nom $/b) nom $/b  \
# Year
# 2050               214.277344                                 205.581665
# 2049               206.792648                                 198.653381
# 2048               198.939514                                 190.964218
# 2047               191.102951                                 182.914185
# 2046               183.427155                                 174.213318
#
#       Gas Price at Henry Hub (nom $/MMBtu) nom $/MMBtu  \
# Year
# 2050                                          7.539873
# 2049                                          7.266372
# 2048                                          7.051677
# 2047                                          6.823333
# 2046                                          6.579929
#
#       Coal at Minemouth (nom $/ton) nom $/ton  \
# Year
# 2050                                77.163956
# 2049                                75.155357
# ...

# %%
Energy_Price = Energy_Norminal_Price.loc[:, ['West Texas Intermediate (nom $/b) nom $/b', 'Gas Price at Henry Hub (nom $/MMBtu) nom $/MMBtu', 'Coal at Minemouth (nom $/ton) nom $/ton', 'Electricity (nom cents/kWh) nom cents/kWh']]
Energy_Price.head()
# Out:
#       West Texas Intermediate (nom $/b) nom $/b  \
# Year
# 2050                                 205.581665
# 2049                                 198.653381
# 2048                                 190.964218
# 2047                                 182.914185
# 2046                                 174.213318
#
#       Gas Price at Henry Hub (nom $/MMBtu) nom $/MMBtu  \
# Year
# 2050                                          7.539873
# 2049                                          7.266372
# 2048                                          7.051677
# 2047                                          6.823333
# 2046                                          6.579929
#
#       Coal at Minemouth (nom $/ton) nom $/ton  \
# Year
# 2050                                77.163956
# 2049                                75.155357
# 2048                                73.135712
# 2047                                71.197189
# 2046                                69.313484
#
# ...

# %%
#Used concat to combine the Production and Norminal price data and idexed it by years
Prod_Price_combined_df = pd.concat([nonrenewable_production, Energy_Price], axis="columns", join="inner")
Prod_Price_combined_df
# Out:
#       Crude Oil and Lease Condensate quads  Natural Gas Plant Liquids quads  \
# Year
# 2050                             24.796230                         8.190884
# 2049                             25.881308                         8.390840
# 2048                             26.494122                         8.449029
# 2047                             27.029858                         8.443357
# 2046                             27.620865                         8.467919
# 2045                             28.151617                         8.544112
# 2044                             28.623829                         8.584071
# 2043                             28.954979                         8.620247
# 2042                             29.058006                         8.613832
# 2041                             29.041647                         8.611508
# 2040                             28.853626                         8.595632
# ...

# %%
#Used concat to combine the consumption and Norminal price data and idexed it by years
Consu_Price_combined_df = pd.concat([Nonrenewable_Consumption, Energy_Price], axis="columns", join="inner")
Consu_Price_combined_df
# Out:
#       Liquid Fuels quads  Natural Gas quads  Coal quads  Nuclear quads  \
# Year
# 2050           38.663658          37.810448    7.936447       6.716295
# 2049           38.416660          37.552456    7.910830       6.711448
# 2048           38.181633          37.169861    7.944196       6.708094
# 2047           37.954109          36.785000    7.953084       6.705318
# 2046           37.730907          36.443565    7.962496       6.700862
# 2045           37.533596          36.243198    7.896763       6.696404
# 2044           37.317387          36.082645    7.933951       6.687841
# 2043           37.145874          35.940025    7.935738       6.679939
# 2042           36.995640          35.729935    7.965323       6.762374
# 2041           36.865440          35.527851    7.995692       6.752901
# 2040           36.747784          35.316647    8.031965       6.739802
# 2039           36.704563          34.983902    8.057528       6.828832
# ...

# %%
#Used concat to combine the consumption and Production data and idexed it by years
Consu_Prod_combined_df = pd.concat([nonrenewable_production, Nonrenewable_Consumption], axis="columns", join="inner")
Consu_Prod_combined_df
# Out:
#       Crude Oil and Lease Condensate quads  Natural Gas Plant Liquids quads  \
# Year
# 2050                             24.796230                         8.190884
# 2049                             25.881308                         8.390840
# 2048                             26.494122                         8.449029
# 2047                             27.029858                         8.443357
# 2046                             27.620865                         8.467919
# 2045                             28.151617                         8.544112
# 2044                             28.623829                         8.584071
# 2043                             28.954979                         8.620247
# 2042                             29.058006                         8.613832
# 2041                             29.041647                         8.611508
# 2040                             28.853626                         8.595632
# ...

# %%
# Plot the data trends of the two variables over time
Consu_Prod_combined_df.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Plot the data trends of the two variables over time
Prod_Price_combined_df.plot()

#Need better visualization
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Plot the relationship between the two variables
#Prod_Price_combined_df.plot(kind='scatter', x='Total quads', y='Drowning Incidents')

'''Need to identify which relationship to analyze... maybe combine the non-renewable sector and compare to the projected price? and do the same for renewable??? 
I will need to combine the different sectors first and then do the analysis?'''
# Out:
# 'Need to identify which relationship to analyze... maybe combine the non-renewable sector and compare to the projected price? and do the same for renewable??? \nI will need to combine the different sectors first and then do the analysis?'

# %%
# Calculate the correlation between each column
Prod_Price_correlation = Prod_Price_combined_df.corr()
Prod_Price_correlation
# Out:
#                                                   Crude Oil and Lease Condensate quads  \
# Crude Oil and Lease Condensate quads                                          1.000000
# Natural Gas Plant Liquids quads                                               0.532866
# Dry Natural Gas quads                                                        -0.283082
# Coal quads                                                                   -0.107590
# Nuclear quads                                                                 0.019336
# Other quads                                                                  -0.441207
# West Texas Intermediate (nom $/b) nom $/b                                    -0.524802
# Gas Price at Henry Hub (nom $/MMBtu) nom $/MMBtu                             -0.450359
# Coal at Minemouth (nom $/ton) nom $/ton                                      -0.538212
# Electricity (nom cents/kWh) nom cents/kWh                                    -0.469203
#
# ...

# %%
# Use the `heatmap` function from the Seaborn library to visualize correlations
sns.heatmap(Prod_Price_correlation, vmin=-1, vmax=1)
"""Need to understand the interpretation of this visualization" maybe need to combine a sectors (renewable vs non-renewable) together to get a better understanding."""
# Out:
# 'Need to understand the interpretation of this visualization" maybe need to combine a sectors (renewable vs non-renewable) together to get a better understanding.'

# %%
Consu_Price_correlation = Consu_Price_combined_df.corr()
Consu_Price_combined_df
# Out:
#       Liquid Fuels quads  Natural Gas quads  Coal quads  Nuclear quads  \
# Year
# 2050           38.663658          37.810448    7.936447       6.716295
# 2049           38.416660          37.552456    7.910830       6.711448
# 2048           38.181633          37.169861    7.944196       6.708094
# 2047           37.954109          36.785000    7.953084       6.705318
# 2046           37.730907          36.443565    7.962496       6.700862
# 2045           37.533596          36.243198    7.896763       6.696404
# 2044           37.317387          36.082645    7.933951       6.687841
# 2043           37.145874          35.940025    7.935738       6.679939
# 2042           36.995640          35.729935    7.965323       6.762374
# 2041           36.865440          35.527851    7.995692       6.752901
# 2040           36.747784          35.316647    8.031965       6.739802
# 2039           36.704563          34.983902    8.057528       6.828832
# ...

# %%
# Calculate the correlation between each column
Consu_Price_correlation = Consu_Price_combined_df.corr()
Consu_Price_correlation
# Out:
#                                                   Liquid Fuels quads  \
# Liquid Fuels quads                                          1.000000
# Natural Gas quads                                           0.265401
# Coal quads                                                  0.342609
# Nuclear quads                                               0.413827
# West Texas Intermediate (nom $/b) nom $/b                   0.141556
# Gas Price at Henry Hub (nom $/MMBtu) nom $/MMBtu            0.024951
# Coal at Minemouth (nom $/ton) nom $/ton                     0.166945
# Electricity (nom cents/kWh) nom cents/kWh                   0.062906
#
#                                                   Natural Gas quads  \
# Liquid Fuels quads                                         0.265401
# Natural Gas quads                                          1.000000
# Coal quads                                                -0.654906
# Nuclear quads                                             -0.708748
# ...

# %%
sns.heatmap(Consu_Price_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
# Calculate the correlation between each column
Consu_Prod_correlation = Consu_Prod_combined_df.corr()
Consu_Prod_correlation
# Out:
#                                       Crude Oil and Lease Condensate quads  \
# Crude Oil and Lease Condensate quads                              1.000000
# Natural Gas Plant Liquids quads                                   0.532866
# Dry Natural Gas quads                                            -0.283082
# Coal quads                                                       -0.107590
# Nuclear quads                                                     0.019336
# Other quads                                                      -0.441207
# Liquid Fuels quads                                               -0.749406
# Natural Gas quads                                                -0.582127
# Coal quads                                                       -0.156293
# Nuclear quads                                                     0.019336
#
#                                       Natural Gas Plant Liquids quads  \
# Crude Oil and Lease Condensate quads                         0.532866
# ...

# %% [markdown]
# Consumption & Production Correlation

# %%
sns.heatmap(Consu_Prod_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>
